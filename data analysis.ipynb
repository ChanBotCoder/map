# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Chandru\Desktop\chandru T-2003 test_project\analysis_project\uploads\fine_stiudent_data.csv")
data
# Out:
#      Reg. Number         Stud. Name  AD3251  AD3271  BE3251  GE3251  GE3271  \
# 0   611221243001           AARTHI L       9      10       7       7      10
# 1   611221243002          ABIRAMI D       8       9       0       7      10
# 2   611221243003          AKILRAJ S       7       9       7       8       9
# 3   611221243004          AKSHAYA N       8      10       7       7      10
# 4   611221243005  ANTONY DANIEL M F       7       9       7       7      10
# ..           ...                ...     ...     ...     ...     ...     ...
# 56  611221243059            SURYA B       7       9       7       8       9
# 57  611221243060      VENKATESH S R       9      10       8       9      10
# 58  611221243061      VIDHUMITHAA G       9       9       7       8       9
# 59  611221243062           VIDHYA B       8      10       7       9      10
# 60  611221243063       VIJAYKUMAR S       8       9       7       7       8
#
#     HS3251  MA3251  PH3256   RA      CGPA
# ...

# %%
remove_col=['Reg. Number','Stud. Name','RA','CGPA']

# %%
for i in range(0,len(remove_col)):
    data= data.drop(remove_col[i],axis='columns')
data.columns

# %%
subject =[i for i in data.columns]
subject
